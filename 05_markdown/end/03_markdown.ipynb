# %% [markdown]
# # 03 Markdown introduction
#
# ***

# %% [markdown]
# ## Headings
#
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4

# %% [markdown]
# ## Horizontal Rules
#
# ***
# ---
#
# Some Text

# %% [markdown]
# ## Paragraphs
#
# Paragraph 1
#
# Paragraph 2
#
# Paragraph 3

# %% [markdown]
# ## Line breaks
#
# Use double space (two or more spaces) at the end of the line for line breaks.
#
# This is
# one line
#
# These are
# Two lines (using double space)

# %% [markdown]
# ## Font
#
# *Italics*
# **Bold**

# %% [markdown]
# ## Lists
#
# Bullet points:
# * Point 1
# * Point 2
#
# Numbered list:
# 1. First item
# 2. Second item

# %% [markdown]
# ## Images
#
# <img src="img/img.png" width="700">

# %% [markdown]
# ## Links
#
# Link to my [github](https://github.com/).
#
# Link to Section [Images](#Images).

# %% [markdown]
# ## Equations
#
# LaTex code in-line: $A = \pi r^2$.
# LaTex code over several lines:
# $$
# A = \pi r^2
# perimeter = 2 \pi r
# $$

# %% [markdown]
# ## Code
#
# Code block in-line: `var = 2`.
# Code block over several lines:
# ```
# var = 2
# print(var)
# ```

# %% [markdown]
# ## Blockquotes
#
# Blockquotes are used to emphasize important information.
#
# > Some text.
