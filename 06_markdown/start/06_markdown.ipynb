# %% [markdown]
# # Markdown introduction
#
# ## Strut'n'Tie — Python in Structural Engineering
# ### Video 06
#
# **Author:** Kamil Riedel
# **© Strut'n'Tie**
# **License:** MIT Licence

# %% [markdown]
# ## Headings

# %% [markdown]
# ## Horizontal Rules

# %% [markdown]
# ## Paragraphs

# %% [markdown]
# ## Line breaks

# %% [markdown]
# ## Font Formatting

# %% [markdown]
# ## Lists

# %% [markdown]
# ## Images

# %% [markdown]
# ## Links

# %% [markdown]
# ## Equations

# %% [markdown]
# ## Code

# %% [markdown]
# ## Blockquotes

# %% [markdown]
# ## Tables
