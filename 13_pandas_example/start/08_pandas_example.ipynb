# %% [markdown]
# Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Sections

# %% [markdown]
# ## Section resistance
#
# $F_{Rd} = \sigma * A$
#
# $M_{Rd,y} = W_{yy} * \sigma$

# %% [markdown]
# ## Beam elements

# %% [markdown]
# ## Element results

# %% [markdown]
# ## Column elements

# %% [markdown]
# ## Column utilisation

# %%
# Add line column

# %%
# Add section column

# %%
# Add resistances

# %%
# Add utilisation column

# %%
# Get maximum utilisation
